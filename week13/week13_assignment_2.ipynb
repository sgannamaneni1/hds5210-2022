# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
#code to read the data file and display the rows and column count
final_project = pd.read_csv('Life_Expectancy_Data.csv')
final_project.shape
# Out:
# (2938, 22)

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
# Unique values present in each column
unique=final_project
unique=unique.nunique().rename_axis('Column Name').reset_index(name='Unique Counts')
unique
# Out:
#                         Column Name  Unique Counts
# 0                           Country            193
# 1                              Year             16
# 2                            Status              2
# 3                  Life expectancy             362
# 4                   Adult Mortality            425
# 5                     infant deaths            209
# 6                           Alcohol           1076
# 7            percentage expenditure           2328
# 8                       Hepatitis B             87
# 9                          Measles             958
# 10                             BMI             608
# 11               under-five deaths             252
# 12                            Polio             73
# 13                Total expenditure            818
# 14                      Diphtheria              81
# 15                         HIV/AIDS            200
# 16                              GDP           2490
# ...

# %%
# Code to identify column with greatest number of distinct values
unique=unique.sort_values(by='Unique Counts', ascending=False).reset_index()
unique=unique.loc[0,'Column Name']
unique
# Out:
# 'GDP'

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
# find redundant columns
for i , col in enumerate(final_project.columns):
    values = pd.unique(final_project.iloc[:, i])
    if len(values) == 1:
        # col with only one unique entry
        print("col: {} with redundant_value: {}".format(col, values[0]))

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
# Created histogram for infant deaths and Year Columns
plt.hist(final_project['infant deaths'],bins=9)
# Out:
# (array([2.852e+03, 5.100e+01, 1.900e+01, 0.000e+00, 2.000e+00, 3.000e+00,
#         3.000e+00, 3.000e+00, 5.000e+00]),
#  array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400., 1600.,
#         1800.]),
#  <a list of 9 Patch objects>)

# %%
plt.hist(final_project['Year'])
# Out:
# (array([366., 183., 366., 183., 366., 183., 366., 183., 376., 366.]),
#  array([2000. , 2001.5, 2003. , 2004.5, 2006. , 2007.5, 2009. , 2010.5,
#         2012. , 2013.5, 2015. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
# dtypes per column
final_project.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
# checking for null values
final_project.isnull()
# Out:
#       Country   Year  Status  Life expectancy   Adult Mortality  \
# 0       False  False   False             False            False
# 1       False  False   False             False            False
# 2       False  False   False             False            False
# 3       False  False   False             False            False
# 4       False  False   False             False            False
# ...       ...    ...     ...               ...              ...
# 2933    False  False   False             False            False
# 2934    False  False   False             False            False
# 2935    False  False   False             False            False
# 2936    False  False   False             False            False
# 2937    False  False   False             False            False
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             False    False                   False        False     False
# ...

# %%
#Barplot for infant deaths vs countries
plt.bar(final_project['Country'],final_project['infant deaths'])
plt.title("infant deaths")
plt.xlabel("Countries")
plt.ylabel("Number of infant deaths")
plt.show()

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
